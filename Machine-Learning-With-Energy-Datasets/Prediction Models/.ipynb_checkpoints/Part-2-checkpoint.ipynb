# %%
import pandas as pd
import numpy as np
import operator
from math import sqrt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from matplotlib import pyplot as plt
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingRegressor  
from sklearn import cross_validation, metrics   
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import LeaveOneLabelOut
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor 
import datetime
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## IMPORTING DATASET

# %%
df = pd.read_csv("energydata_complete.csv")

# %%
df.apply(lambda x: sum(x.isnull()))
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>29 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>19735 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>4.4 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>232.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>25 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>3 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>T9</code> is highly correlated with <code>T7</code> (ρ = 0.94478) <span class="label label-primary">Rejected</span></l><li><code>T_out</code> is highly correlated with <code>T6</code> (ρ = 0.97478) <span class="label label-primary">Rejected</span></l><li><code>lights</code> has 15252 / 77.3% zeros</l><li><code>rv2</code> is highly correlated with <code>rv1</code> (ρ = 1) <span class="label label-primary">Rejected</span></l> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4">Appliances<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>92</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>0.5%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n)</th>
#                     <td>0</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (n)</th>

# %% [markdown]
# ## ONE HOT ENCODING

# %%
df['date'] = pd.to_datetime(df.date)

df['weekday'] = df['date'].dt.strftime('%A')

df['Month'] = df['date'].dt.strftime('%m').astype('int64')

df['Week_no'] = df['date'].dt.strftime('%W').astype('int64')

df['Hour_of_the_day'] = df['date'].dt.strftime('%H').astype('int64')

df['NSM'] = df['date'].dt.strftime('%H:%M:%S')
df['NSM'] = df['NSM'].str.split(':').apply(lambda x: int(x[0]) * 3600 + int(x[1]) *60 + int(x[2]))

df['WeekStatus'] = (df['date'].dt.strftime('%w').astype(int) < 5).astype('int64')

df['date'] = df['date'].dt.strftime('%Y-%m-%d %H:%M:%S')

W_Status = pd.get_dummies(df.WeekStatus,prefix='W_Status').astype('int64')
Day_W = pd.get_dummies(df.weekday, prefix = 'Dy_w').astype('int64')

df = pd.concat([df,W_Status,Day_W],axis=1)

# %%
featureColumns = ['Appliances','NSM','lights','T1','RH_1','T2','RH_2','T3','RH_3','T4','RH_4','T5','RH_5','T6','RH_6',
                  'T7','RH_7','T8','RH_8','T9','RH_9','T_out','RH_out','Visibility','Windspeed','Tdewpoint',
                  'Press_mm_hg','W_Status_1','W_Status_0',
                  'Dy_w_Monday','Dy_w_Tuesday','Dy_w_Wednesday','Dy_w_Thursday',
                  'Dy_w_Friday','Dy_w_Saturday','Dy_w_Sunday']

# %%
df = df[featureColumns]

# %% [markdown]
# ## TEST TRAIN SPLIT

# %%
X = df.drop(['Appliances'],axis=1)
y = df['Appliances']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## RFE USING RANDOM FOREST

# %%
model = RandomForestRegressor(n_estimators=300, max_features = 11)
    # create the RFE model and select 3 attributes
rfe = RFE(model)
rfe = rfe.fit(X_train, y_train)
    # summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
print(rfe.n_features_)
    #Check the accuracy of the model
rfe.score(X_train, y_train)
# Out:
# [ True False False  True False  True  True  True  True  True False  True
#   True  True False  True  True  True False  True False  True False False
#   True  True False False False False False False False False False]
# [ 1  6  5  1  3  1  1  1  1  1  2  1  1  1  7  1  1  1  9  1  4  1 10  8
#   1  1 13 11 12 17 19 18 14 15 16]
# 17
# 0.9443590615322105

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()

# %%
X_train_minmax = min_max.fit_transform(X_train)

# %%
X_test_minmax=min_max.fit_transform(X_test)

# %% [markdown]
# ## SCALING THE DATA

# %%
scaler = StandardScaler()

# %%
X_train_scale=scaler.fit_transform(X_train)

# %%
X_test_scale=scaler.fit_transform(X_test)

# %% [markdown]
# ## ERROR METRICS

# %%
error_metric = pd.DataFrame({'r2_train': [],
                            'r2_test': [],
                             'rms_train':[], 
                            'rms_test': [],
                            'mae_train': [],
                            'mae_test':[],
                            'mape_train':[],
                            'mape_test':[]})
    
rmse_dict = {}    
        
def calc_error_metric(modelname, model, X_train_scale, y_train, X_test_scale, y_test):
    global error_metric
    y_train_predicted = model.predict(X_train)
    y_test_predicted = model.predict(X_test)
        
    #MAE, RMS, MAPE, R2
    
    r2_train = r2_score(y_train, y_train_predicted)
    r2_test = r2_score(y_test, y_test_predicted)
    
    rms_train = sqrt(mean_squared_error(y_train, y_train_predicted))
    rms_test = sqrt(mean_squared_error(y_test, y_test_predicted))
        
    mae_train = mean_absolute_error(y_train, y_train_predicted)
    mae_test = mean_absolute_error(y_test, y_test_predicted)
        
    mape_train = np.mean(np.abs((y_train - y_train_predicted) / y_train)) * 100
    mape_test = np.mean(np.abs((y_test - y_test_predicted) / y_test)) * 100
        
    rmse_dict[modelname] = rms_test
        
    df_local = pd.DataFrame({'Model':[modelname],
                            'r2_train': [r2_train],
                            'r2_test': [r2_test],
                            'rms_train':[rms_train], 
                            'rms_test': [rms_test],
                            'mae_train': [mae_train],
                            'mae_test': [mae_test],
                            'mape_train':[mape_train],
                            'mape_test':[mape_test]})
        
    error_metric = pd.concat([error_metric, df_local])
    return error_metric

# %% [markdown]
# ## PREDICTION MODELS

# %%
# Regression
clf = LinearRegression()
clf.fit(X_train, y_train)
calc_error_metric('Regression', clf, X_train, y_train, X_test, y_test)
print('Regression completed')

# Random Forest
rf = RandomForestRegressor(n_estimators=100, max_depth=7)
rf.fit(X_train, y_train)
calc_error_metric('RandomForest', rf, X_train, y_train, X_test, y_test)
print('RandomForest completed')
    
# Neural network
nn = MLPRegressor()
nn.fit(X_train, y_train)
calc_error_metric('Nueral Network', nn, X_train, y_train, X_test, y_test)
print('Neural Network completed')
    
#### Calculate best model
best_model =  min(rmse_dict.items(),key=operator.itemgetter(1))[0]
print('Best Model is ', best_model)
    
#### Write the error
error_metric.to_csv('Error_metrics.csv')
# Out:
# Regression completed
# RandomForest completed
# Neural Network completed
# Best Model is  RandomForest

# %%
import yellowbrick as yb
from yellowbrick.regressor import ResidualsPlot
ridge = LinearRegression()
visualizer = ResidualsPlot(ridge)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
g = visualizer.poof()

# %%
# Regression
clf = LinearRegression(n_jobs = -1)
clf.fit(X_train, y_train)
calc_error_metric('Regression', clf, X_train, y_train, X_test, y_test)
print('Regression completed')

# Random Forest
rf = RandomForestRegressor(n_estimators=115,max_features=6)
rf.fit(X_train, y_train)
calc_error_metric('RandomForest', rf, X_train, y_train, X_test, y_test)
print('RandomForest completed')
     
# Neural network
nn = MLPRegressor(activation='logistic',learning_rate='adaptive',alpha=0.3)
nn.fit(X_train, y_train)
calc_error_metric('Neural Network', nn, X_train, y_train, X_test, y_test)
print('Neural Network completed')
    
#### Calculate best model
best_model =  min(rmse_dict.items(),key=operator.itemgetter(1))[0]
print('Best Model is ', best_model)
# Out:
# Regression completed
# RandomForest completed
# Neural Network completed
# Best Model is  RandomForest

# %%
error_metric
# Out:
#             Model   mae_test  mae_train  mape_test  mape_train   r2_test  \
# 0      Regression  52.954546  53.124709  63.023106   61.001825  0.163900
# 0    RandomForest  45.598505  44.191783  50.849607   47.258281  0.279662
# 0  Nueral Network  79.263176  80.554313  72.083939   72.194250 -0.710046
# 0      Regression  52.954546  53.124709  63.023106   61.001825  0.163900
# 0    RandomForest  29.773638  11.577255  29.601453   11.305133  0.597038
# 0  Neural Network  55.226657  55.983226  67.896143   66.447510  0.050649
#
#    r2_train    rms_test   rms_train
# 0  0.176196   91.135629   93.898834
# 0  0.363465   84.591583   82.539001
# 0 -0.681536  130.335547  134.153258
# 0  0.176196   91.135629   93.898834
# 0  0.941718   63.269016   24.975548
# 0  0.048882   97.111908  100.894029

# %% [markdown]
# ## RF FEATURE IMPORTANCE PLOT

# %%
feat_imp = pd.Series(rf.feature_importances_,X_train.columns).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances',figsize = (15,8))
plt.ylabel('Feature Importance Score')
# Out:
# Text(0,0.5,'Feature Importance Score')

# %% [markdown]
# ## GBM

# %%
gbrt=GradientBoostingRegressor(n_estimators= 300,learning_rate = 1.0, max_features= 'sqrt') 

gbrt.fit(X_train, y_train)
y_pred=gbrt.predict(X_test) 

print ("Feature Importances" )
print (gbrt.feature_importances_)
       

print ("R-squared for Train: %.2f" %gbrt.score(X_train, y_train))
print ("R-squared for Test: %.2f" %gbrt.score(X_test, y_test))
# Out:
# Feature Importances
# [0.04603401 0.00770108 0.03479227 0.04087001 0.0322403  0.04232805
#  0.04867506 0.03941504 0.03674387 0.04109261 0.0399643  0.04091841
#  0.04530991 0.03257869 0.03692423 0.03785159 0.04480123 0.05095012
#  0.03088877 0.04313381 0.0316952  0.0393292  0.01704609 0.02440869
#  0.03426141 0.05590598 0.00304803 0.00371272 0.00255189 0.00160702
#  0.00092786 0.00223997 0.00609188 0.00220921 0.00175148]
# R-squared for Train: 0.76
# R-squared for Test: 0.31

# %% [markdown]
# ## GBM WITH GRID SEARCH CV

# %%
def GradientBooster(param_grid, n_jobs): 
    estimator = GradientBoostingRegressor()
    cv = LeaveOneLabelOut(X_train.shape)
    classifier = GridSearchCV(estimator=estimator, cv=cv, param_grid=param_grid, n_jobs=n_jobs) 
    classifier.fit(X_train, y_train)
    print("Best Estimator learned through GridSearch" )
    classifier.best_estimator_ 
    return classifier.best_estimator_

# %%
param_grid={'n_estimators':[300], 
            'learning_rate': [0.1],# 0.05, 0.02, 0.01], 
            'max_depth':[6],#4,6], 
            'min_samples_leaf':[5],#,5,9,17], 
            'max_features':[1.0] #,0.3]#,0.1]
           } 
n_jobs = 7 
best_est=GradientBooster(param_grid, n_jobs)
# Out:
# Best Estimator learned through GridSearch

# %%
print("Best Estimator Parameters") 
print("---------------------------")
print("n_estimators: %d" %best_est.n_estimators)
print("max_depth: %d" %best_est.max_depth)
print("Learning Rate: %.1f" %best_est.learning_rate)
print("min_samples_leaf: %d" %best_est.min_samples_leaf)
print("max_features: %.1f" %best_est.max_features) 
print("Train R-squared: %.2f" %best_est.score(X_train,y_train))
print("Test R-squared: %.2f" %best_est.score(X_test,y_test))
print("Train RMSE : %.2f"%sqrt(mean_squared_error(y_train, best_est.predict(X_train))))
print("Test RMSE : %.2f "%sqrt(mean_squared_error(y_test, best_est.predict(X_test))))
# Out:
# Best Estimator Parameters
# ---------------------------
# n_estimators: 300
# max_depth: 6
# Learning Rate: 0.1
# min_samples_leaf: 5
# max_features: 1.0
# Train R-squared: 0.84
# Test R-squared: 0.54
# Train RMSE : 41.35
# Test RMSE : 67.96

# %%
feat_imp = pd.Series(best_est.feature_importances_,X_train.columns).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances',figsize = (15,8))
plt.ylabel('Feature Importance Score')
# Out:
# Text(0,0.5,'Feature Importance Score')

# %% [markdown]
# ## no lights

# %%
nolights = ['NSM','T1','RH_1','T2','RH_2','T3','RH_3','T4','RH_4','T5','RH_5',
                  'T6','RH_6','T7','RH_7','T8','RH_8','T9','RH_9','T_out','RH_out','Visibility',
                  'Windspeed','Tdewpoint','Press_mm_hg','W_Status_0','W_Status_1',
                  'Dy_w_Monday','Dy_w_Tuesday','Dy_w_Wednesday',
                  'Dy_w_Thursday','Dy_w_Friday','Dy_w_Saturday','Dy_w_Sunday']

# %% [markdown]
# ## no lights and weather data

# %%
nolightsWeather = ['NSM','T1','RH_1','T2','RH_2','T3','RH_3','T4','RH_4','T5','RH_5',
                  'T6','RH_6','T7','RH_7','T8','RH_8','T9','RH_9','W_Status_0','W_Status_1',
                  'Dy_w_Monday','Dy_w_Tuesday','Dy_w_Wednesday',
                  'Dy_w_Thursday','Dy_w_Friday','Dy_w_Saturday','Dy_w_Sunday']

# %%
XtrainNew = X_train[timeweather]
XtestNew = X_test[timeweather]

# %%
rf = RandomForestRegressor(n_estimators=115,max_features=6)
rf.fit(XtrainNew, y_train)
cl_error_metric('RandomForest', rf, XtrainNew, y_train, XtestNew, y_test)
# Out:
#             Model   mae_test  mae_train  mape_test  mape_train   r2_test  \
# 0      Regression  52.954546  53.124709  63.023106   61.001825  0.163900
# 0    RandomForest  45.526128  44.061829  50.886201   47.195757  0.281028
# 0  Nueral Network  52.580637  53.028968  62.151672   60.039813  0.111306
# 0      Regression  52.954546  53.124709  63.023106   61.001825  0.163900
# 0    RandomForest  29.610952  11.577408  29.320830   11.341582  0.600921
# 0  Neural Network  52.467578  53.314667  59.486755   58.293158  0.024052
# 0    RandomForest  29.177861  11.383796  28.846193   11.000800  0.614864
# 0    RandomForest  28.989678  11.284422  28.748943   10.983378  0.618526
# 0    RandomForest  28.915405  11.232608  28.510477   10.899184  0.619958
# 0    RandomForest  29.260664  11.472033  30.079396   11.562508  0.632823
# 0    RandomForest  29.203815  11.417895  29.655951   11.403135  0.627837
#
#    r2_train   rms_test   rms_train
# 0  0.176196  91.135629   93.898834
# 0  0.367736  84.511366   82.261676
# 0  0.112802  93.958318   97.444756
# 0  0.176196  91.135629   93.898834
# 0  0.942823  62.963464   24.737694
# 0  0.021077  98.462826  102.358162
# 0  0.941848  61.853734   24.947784
# 0  0.943312  61.559025   24.631617
# 0  0.943872  61.443321   24.509777
# 0  0.944909  60.394410   24.282203
# 0  0.944397  60.803061   24.394747

# %%
def cl_error_metric(modelname, model, XtrainNew, y_train, XtestNew, y_test):
    global error_metric
    y_train_predicted = model.predict(XtrainNew)
    y_test_predicted = model.predict(XtestNew)
        
    #MAE, RMS, MAPE, R2
    
    r2_train = r2_score(y_train, y_train_predicted)
    r2_test = r2_score(y_test, y_test_predicted)
    
    rms_train = sqrt(mean_squared_error(y_train, y_train_predicted))
    rms_test = sqrt(mean_squared_error(y_test, y_test_predicted))
        
    mae_train = mean_absolute_error(y_train, y_train_predicted)
    mae_test = mean_absolute_error(y_test, y_test_predicted)
        
    mape_train = np.mean(np.abs((y_train - y_train_predicted) / y_train)) * 100
    mape_test = np.mean(np.abs((y_test - y_test_predicted) / y_test)) * 100
        
    rmse_dict[modelname] = rms_test
        
    df_local = pd.DataFrame({'Model':[modelname],
                            'r2_train': [r2_train],
                            'r2_test': [r2_test],
                            'rms_train':[rms_train], 
                            'rms_test': [rms_test],
                            'mae_train': [mae_train],
                            'mae_test': [mae_test],
                            'mape_train':[mape_train],
                            'mape_test':[mape_test]})
        
    error_metric = pd.concat([error_metric, df_local])
    return error_metric

# %% [markdown]
# ## no Temperature and Humidity inside house

# %%
notempHumididty = ['NSM','T_out','RH_out','Visibility',
                  'Windspeed','Tdewpoint','Press_mm_hg','W_Status_0','W_Status_1',
                  'Dy_w_Monday','Dy_w_Tuesday','Dy_w_Wednesday',
                  'Dy_w_Thursday','Dy_w_Friday','Dy_w_Saturday','Dy_w_Sunday']

# %%
# Random Forest
r2_train,r2_test

# %% [markdown]
# ## only weather and time information

# %%
timeweather = ['NSM','T_out','RH_out','Visibility',
                  'Windspeed','Tdewpoint','Press_mm_hg','W_Status_0','W_Status_1',
                  'Dy_w_Monday','Dy_w_Tuesday','Dy_w_Wednesday',
                  'Dy_w_Thursday','Dy_w_Friday','Dy_w_Saturday','Dy_w_Sunday']

# %% [markdown]
# ## Random Forest with Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid1 = {
    'bootstrap': [True],
    'max_features': [4,6,11],
    'n_estimators': [300]
}

# Create a based model
rfr = RandomForestRegressor()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rfr, param_grid = param_grid1, 
                          cv = 10, n_jobs = -1, verbose = 3)
grid_search.fit(XtrainNew,y_train)

#BEst Estimator
best_grid = grid_search.best_estimator_
best_grid.feature_importances_

#Finding R2
r2_train = r2_score(y_train, grid_search.predict(XtrainNew))
r2_test = r2_score(y_test, grid_search.predict(XtestNew))
r2_train, r2_test


#Plotting graph 
feat_imp = pd.Series(best_grid.feature_importances_,XtrainNew.columns).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances',figsize = (15,8))
plt.ylabel('Feature Importance Score')
# Out:
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done  26 out of  30 | elapsed:  2.5min remaining:   23.2s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  2.9min finished
# Text(0,0.5,'Feature Importance Score')

# %% [markdown]
# ## TPOT

# %%
from tpot import TPOTRegressor

tpot = TPOTRegressor(generations=10, population_size=10,offspring_size=None, mutation_rate=0.9, verbosity=3)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
tpot.export('tpot_pipeline.py')

# %%
from sklearn.linear_model import Ridge
clf = Ridge(alpha=1.0)
clf.fit(X_train, y_train)

# %%
clf.predict(X_train)

# %%
clf.score(X_train, y_train)

# %%
from sklearn.linear_model import ElasticNetCV

regr = ElasticNetCV(cv=5, random_state=0)
regr.fit(X_train, y_train)

# %%
regr.predict(X_train)

# %%
regr.score(X_train, y_train)
