# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import date
import calendar
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
import operator

# %%
df=pd.read_csv('../Data/energydata_complete.csv',index_col='date',header=0)
df['datetime'] = df.index
df['datetime'] = pd.to_datetime(df['datetime'])
df['day_of_week']=df['datetime'].dt.strftime('%w').astype('int64')
df['month']=df['datetime'].dt.strftime('%m').astype('int64')
df['hour']=df['datetime'].dt.hour
df['day_number']=df['datetime'].dt.day
df['Week_no'] = df['datetime'].dt.strftime('%W').astype('int64')
df['min'] = df['datetime'].dt.minute
df['day_of_week']=df['day_of_week'].apply(str)
df['hour']=df['hour'].apply(str)
df['min']=df['min'].apply(str)
df['period']=df[['day_of_week','hour','min']].apply(lambda x:''.join(x),axis=1)
phase = df.groupby(['date','month','day_of_week','hour','day_number','min','datetime','period']).mean()
phase["Total"]=phase["Appliances"] + phase["lights"]
phase = phase.reset_index()
phase.set_index('date', inplace=True)
phase['datetime1'] = df.index
phase['day_of_week']=phase['day_of_week'].apply(int)
phase['hour']=phase['hour'].apply(int)
phase['min']=phase['min'].apply(int)
phase['period']=phase['period'].apply(int)
phase['Press_mm_hg'] = np.log(phase['Press_mm_hg'])
phase['Visibility'] = np.log(phase['Visibility'])

phase1 = phase
phase1.drop(['datetime1','Total','rv1','rv2'],axis=1,inplace=True)
y = phase1["Appliances"]
X=phase1.drop("Appliances",axis=1)

# %%
phase.dtypes
# Out:
# month                   int64
# day_of_week             int64
# hour                    int64
# day_number              int64
# min                     int64
# datetime       datetime64[ns]
# period                  int64
# Appliances              int64
# lights                  int64
# T1                    float64
# RH_1                  float64
# T2                    float64
# RH_2                  float64
# T3                    float64
# RH_3                  float64
# T4                    float64
# RH_4                  float64
# T5                    float64
# RH_5                  float64
# T6                    float64
# RH_6                  float64
# T7                    float64
# RH_7                  float64
# T8                    float64
# RH_8                  float64
# T9                    float64
# RH_9                  float64
# T_out                 float64
# Press_mm_hg           float64
# RH_out                float64
# Windspeed             float64
# Visibility            float64
# Tdewpoint             float64
# Week_no                 int64
# dtype: object

# %%
phase
# Out:
#                      month  day_of_week  hour  day_number  min  period  \
# date
# 2016-01-11 17:00:00      1            1    17          11    0    1170
# 2016-01-11 17:10:00      1            1    17          11   10   11710
# 2016-01-11 17:20:00      1            1    17          11   20   11720
# 2016-01-11 17:30:00      1            1    17          11   30   11730
# 2016-01-11 17:40:00      1            1    17          11   40   11740
# 2016-01-11 17:50:00      1            1    17          11   50   11750
# 2016-01-11 18:00:00      1            1    18          11    0    1180
# 2016-01-11 18:10:00      1            1    18          11   10   11810
# 2016-01-11 18:20:00      1            1    18          11   20   11820
# 2016-01-11 18:30:00      1            1    18          11   30   11830
# 2016-01-11 18:40:00      1            1    18          11   40   11840
# 2016-01-11 18:50:00      1            1    18          11   50   11850
# 2016-01-11 19:00:00      1            1    19          11    0    1190
# 2016-01-11 19:10:00      1            1    19          11   10   11910
# 2016-01-11 19:20:00      1            1    19          11   20   11920
# 2016-05-27 16:50:00  55.000000   2.833333    3.098590  13.366667       21
# 2016-05-27 17:00:00  55.000000   3.000000    3.091042  13.400000       21
# 2016-05-27 17:10:00  55.333333   3.166667    3.128221  13.366667       21
# 2016-05-27 17:20:00  55.666667   3.333333    3.164068  13.333333       21
# 2016-05-27 17:30:00  56.000000   3.500000    3.198673  13.300000       21
# 2016-05-27 17:40:00  56.333333   3.666667    3.232121  13.266667       21
# 2016-05-27 17:50:00  56.666667   3.833333    3.264486  13.233333       21
# 2016-05-27 18:00:00  57.000000   4.000000    3.295837  13.200000       21
#
# [19735 rows x 33 columns]

# %% [markdown]
# # Created Package

# %% [markdown]
# ## RMSE,MAPE,R2,MAE calculation

# %%
rmse_dict = {}    
def rmse(correct,estimated):
    rmse_val = np.sqrt(mean_squared_error(correct,estimated)) 
    return rmse_val

def calc_error_metric(name,modelname, model, X_train, y_train, X_test, y_test):
    
    y_train_predicted = model.predict(X_train)
    y_test_predicted = model.predict(X_test)
        
    #MAE, RMS, MAPE, R2
    
    r2_train = r2_score(y_train, y_train_predicted)
    r2_test = r2_score(y_test, y_test_predicted)
    
    rms_train = rmse(y_train, y_train_predicted)
    rms_test = rmse(y_test, y_test_predicted)
        
    mae_train = mean_absolute_error(y_train, y_train_predicted)
    mae_test = mean_absolute_error(y_test, y_test_predicted)
        
    mape_train = np.mean(np.abs((y_train - y_train_predicted) / y_train)) * 100
    mape_test = np.mean(np.abs((y_test - y_test_predicted) / y_test)) * 100
    
    rmse_dict[modelname] = rms_test
        
    df_local = pd.DataFrame({'Model':[name],
                            'ModelType':[modelname],
                            'r2_train': [r2_train],
                            'r2_test': [r2_test],
                            'rms_train':[rms_train], 
                            'rms_test': [rms_test],
                            'mae_train': [mae_train],
                            'mae_test': [mae_test],
                            'mape_train':[mape_train],
                            'mape_test':[mape_test]})

    error_metric = pd.concat([df_local])
 
    return error_metric

# %% [markdown]
# ## RandomForest,LinearRegression,NeuralNetwork

# %%
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

metric = pd.DataFrame({'Model':[],
                            'ModelType':[],
                            'r2_train': [],
                            'r2_test': [],
                            'rms_train':[], 
                            'rms_test': [],
                            'mae_train': [],
                            'mae_test': [],
                            'mape_train':[],
                            'mape_test':[]})


def models(name,X_train, y_train, X_test, y_test):
    global metric
    n = name
    print(name)
    print(type(name))
    print(n)
    print(type(n))
    
    # Linear Regression
    lm = linear_model.LinearRegression()
    modellinear = lm.fit(X_train,y_train)
    linear = calc_error_metric(n ,modellinear,lm, X_train, y_train, X_test, y_test)
    print("LINEAR")
    print(linear)
    
    # Random Forest
    rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
    modelrandomforest = rf.fit(X_train,y_train)
    randomforest = calc_error_metric(name,modelrandomforest,rf, X_train, y_train, X_test, y_test)

    # Neural Network
    nn = MLPRegressor(activation='relu',learning_rate='adaptive',alpha=0.5)
    modelneuralnetwork = nn.fit(X_train, y_train)
    neuralnetwork = calc_error_metric(name,modelneuralnetwork, nn, X_train, y_train, X_test, y_test)
    
    
    metric = pd.concat([metric,linear,randomforest,neuralnetwork])
    return metric

# %% [markdown]
# # Training Testing split

# %%
X = phase1[['lights']]
y = phase1['Appliances']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# # StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit only to the training data
scaler.fit(X_train)
# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
estimated = models('Manual1',X_train, y_train, X_test, y_test)
# Out:
# Manual1
# <class 'str'>
# Manual1
# <class 'str'>
# LINEAR
#      Model                                          ModelType   mae_test  \
# 0  Manual1  LinearRegression(copy_X=True, fit_intercept=Tr...  58.538386
#
#    mae_train  mape_test  mape_train   r2_test  r2_train   rms_test   rms_train
# 0  58.697253  72.418277   71.129393  0.039149  0.038822  99.495142  100.938316

# %%
estimated
# Out:
#      Model                                          ModelType   mae_test  \
# 0  Manual1  LinearRegression(copy_X=True, fit_intercept=Tr...  58.538386
# 0  Manual1  (DecisionTreeRegressor(criterion='mse', max_de...  58.540688
# 0  Manual1  MLPRegressor(activation='relu', alpha=0.5, bat...  58.548565
#
#    mae_train  mape_test  mape_train   r2_test  r2_train   rms_test   rms_train
# 0  58.697253  72.418277   71.129393  0.039149  0.038822  99.495142  100.938316
# 0  58.624099  72.303452   70.957267  0.040906  0.043191  99.404121  100.708621
# 0  58.711191  72.431653   71.146547  0.038814  0.038671  99.512490  100.946203

# %%
rmse_dict
# Out:
# {LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False): 99.495141589892242,
#  RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False): 99.404120793642349,
#  MLPRegressor(activation='relu', alpha=0.5, batch_size='auto', beta_1=0.9,
#         beta_2=0.999, early_stopping=False, epsilon=1e-08,
#         hidden_layer_sizes=(100,), learning_rate='adaptive',
#         learning_rate_init=0.001, max_iter=200, momentum=0.9,
#         nesterovs_momentum=True, power_t=0.5, random_state=None,
#         shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#         verbose=False, warm_start=False): 99.512490218597776}

# %% [markdown]
# # Best Model

# %%
best_model =  min(rmse_dict.items(),key=operator.itemgetter(1))[0]
print('Best Model is ', best_model)
# Out:
# Best Model is  RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# # 2.2 Feature Selection

# %% [markdown]
# ## 2.2.1 Boruta Python Package

# %%
X_boruta = X.values

# %%
y_boruta = y.values

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy

# NOTE BorutaPy accepts numpy arrays only, hence the .values attribute
y_boruta = y_boruta.ravel()

# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
rf1 = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)

# define Boruta feature selection method
feat_selector = BorutaPy(rf1, n_estimators='auto', verbose=2, random_state=1)

# find all relevant features - 5 features should be selected
feat_selector.fit(X_boruta,y_boruta)

# check selected features - first 5 features are selected
feat_selector.support_

# check ranking of features
feat_selector.ranking_

# call transform() on X to filter it down to selected features
X_filtered = feat_selector.transform(X)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	18 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	19 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	20 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	21 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	22 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	23 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	24 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	25 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	26 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	27 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	28 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	29 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	30 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	31 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	32 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	33 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	34 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	35 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	36 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	37 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	38 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	39 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	40 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	41 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	42 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	43 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	44 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	45 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	46 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	47 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	48 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	49 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	50 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	51 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	52 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	53 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	54 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	55 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	56 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	57 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	58 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	59 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	60 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	61 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	62 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	63 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	64 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	65 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	66 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	67 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	68 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	69 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	70 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	71 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	72 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	73 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	74 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	75 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	76 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	77 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	78 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	79 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	80 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	81 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	82 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	83 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	84 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	85 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	86 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	87 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	88 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	89 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	90 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	91 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	92 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	93 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	94 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	95 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	96 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	97 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	98 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
# Iteration: 	99 / 100
# Confirmed: 	0
# Tentative: 	1
# Rejected: 	0
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	0
# Tentative: 	0
# Rejected: 	0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-0c3d1408059f> in <module>()
#      23
#      24 # call transform() on X to filter it down to selected features
# ---> 25 X_filtered = feat_selector.transform(X)
#
# ~/anaconda3/lib/python3.6/site-packages/boruta/boruta_py.py in transform(self, X, weak)
#     220         """
#     221
# --> 222         return self._transform(X, weak)
#     223
#     224     def fit_transform(self, X, y, weak=False):
#
# ~/anaconda3/lib/python3.6/site-packages/boruta/boruta_py.py in _transform(self, X, weak)
#     362             X = X[:, self.support_ + self.support_weak_]
#     363         else:
# --> 364             X = X[:, self.support_]
#     365         return X
#     366
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
print(feat_selector.support_)
# Out:
# [False]

# %%
print(feat_selector.ranking_)
# Out:
# [2]

# %% [markdown]
# ### 2.2.1.1 Check the feaures and select them

# %%
X = phase1[['lights']]
y = phase1['Appliances']

# %% [markdown]
# ### 2.2.1.2 Training Testing split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### 2.2.1.3 RandomForest,LinearRegression,NeuralNetwork

# %%
estimated = models('Boruta',X_train, y_train, X_test, y_test)
# Out:
# Boruta
# <class 'str'>
# Boruta
# <class 'str'>
# LINEAR
#     Model                                          ModelType   mae_test  \
# 0  Boruta  LinearRegression(copy_X=True, fit_intercept=Tr...  58.538386
#
#    mae_train  mape_test  mape_train   r2_test  r2_train   rms_test   rms_train
# 0  58.697253  72.418277   71.129393  0.039149  0.038822  99.495142  100.938316

# %%
estimated
# Out:
#      Model                                          ModelType   mae_test  \
# 0  Manual1  LinearRegression(copy_X=True, fit_intercept=Tr...  58.538386
# 0  Manual1  (DecisionTreeRegressor(criterion='mse', max_de...  58.540688
# 0  Manual1  MLPRegressor(activation='relu', alpha=0.5, bat...  58.548565
# 0   Boruta  LinearRegression(copy_X=True, fit_intercept=Tr...  58.538386
# 0   Boruta  (DecisionTreeRegressor(criterion='mse', max_de...  58.540688
# 0   Boruta  MLPRegressor(activation='relu', alpha=0.5, bat...  58.876926
#
#    mae_train  mape_test  mape_train   r2_test  r2_train   rms_test   rms_train
# 0  58.697253  72.418277   71.129393  0.039149  0.038822  99.495142  100.938316
# 0  58.624099  72.303452   70.957267  0.040906  0.043191  99.404121  100.708621
# 0  58.711191  72.431653   71.146547  0.038814  0.038671  99.512490  100.946203
# 0  58.697253  72.418277   71.129393  0.039149  0.038822  99.495142  100.938316
# 0  58.624099  72.303452   70.957267  0.040906  0.043191  99.404121  100.708621
# 0  59.050151  73.081382   71.799942  0.038995  0.038770  99.503136  100.941017

# %% [markdown]
# ## 2.2.2 FeatureTools

# %%
import featuretools as ft

# %%
phase_featuretools = df.groupby(['date','month','day_of_week','hour','day_number','min','period']).mean()
phase_featuretools = phase_featuretools.reset_index()
phase_featuretools['day_of_week']=phase_featuretools['day_of_week'].apply(int)
phase_featuretools['hour']=phase_featuretools['hour'].apply(int)
phase_featuretools['min']=phase_featuretools['min'].apply(int)
# 2016-01-11 21:40:00   3.766667        2
# 2016-01-11 21:50:00   3.733333        2
# ...                        ...      ...
# 2016-05-27 13:10:00  13.100000       21
# 2016-05-27 13:20:00  13.200000       21
# 2016-05-27 13:30:00  13.300000       21
# 2016-05-27 13:40:00  13.400000       21
# 2016-05-27 13:50:00  13.500000       21
# 2016-05-27 14:00:00  13.600000       21
# 2016-05-27 14:10:00  13.550000       21
# 2016-05-27 14:20:00  13.500000       21
# 2016-05-27 14:30:00  13.450000       21
# 2016-05-27 14:40:00  13.400000       21
# 2016-05-27 14:50:00  13.350000       21
# 2016-05-27 15:00:00  13.300000       21
# 2016-05-27 15:10:00  13.283333       21
# 2016-05-27 15:20:00  13.266667       21
# 2016-05-27 15:30:00  13.250000       21
# 2016-05-27 15:40:00  13.233333       21
# 2016-05-27 15:50:00  13.216667       21
# 2016-05-27 16:00:00  13.200000       21
# 2016-05-27 16:10:00  13.233333       21
# 2016-05-27 16:20:00  13.266667       21
# 2016-05-27 16:30:00  13.300000       21
# 2016-05-27 16:40:00  13.333333       21
# 2016-05-27 16:50:00  13.366667       21
# 2016-05-27 17:00:00  13.400000       21
# 2016-05-27 17:10:00  13.366667       21
# 2016-05-27 17:20:00  13.333333       21
# 2016-05-27 17:30:00  13.300000       21
# 2016-05-27 17:40:00  13.266667       21
# 2016-05-27 17:50:00  13.233333       21
# 2016-05-27 18:00:00  13.200000       21
#
# [19735 rows x 34 columns]

# %%
phase_featuretools1 = phase_featuretools

# %%
y_featuretools = phase_featuretools[['datetime','Appliances']]
X_featuretools = phase_featuretools.drop(['Appliances'],axis=1)
entities ={"appliances" :(y_featuretools,"datetime"),
          "rest" :(X_featuretools,"datetime")}
relationships = [("appliances","datetime","rest","datetime")]

# %%
feature_matrix_app,features_defs = ft.dfs(entities=entities,relationships=relationships,target_entity="appliances")

# %%
feature_matrix_app1 = feature_matrix_app

# %%
feature_matrix_app1.dtypes
# Out:
# Appliances                        int64
# SUM(rest.month)                   int64
# SUM(rest.day_number)              int64
# SUM(rest.lights)                  int64
# SUM(rest.T1)                    float64
# SUM(rest.RH_1)                  float64
# SUM(rest.T2)                    float64
# SUM(rest.RH_2)                  float64
# SUM(rest.T3)                    float64
# SUM(rest.RH_3)                  float64
# SUM(rest.T4)                    float64
# SUM(rest.RH_4)                  float64
# SUM(rest.T5)                    float64
# SUM(rest.RH_5)                  float64
# SUM(rest.T6)                    float64
# SUM(rest.RH_6)                  float64
# SUM(rest.T7)                    float64
# SUM(rest.RH_7)                  float64
# SUM(rest.T8)                    float64
# SUM(rest.RH_8)                  float64
# SUM(rest.T9)                    float64
# SUM(rest.RH_9)                  float64
# SUM(rest.T_out)                 float64
# SUM(rest.Press_mm_hg)           float64
# SUM(rest.RH_out)                float64
# SUM(rest.Windspeed)             float64
# SUM(rest.Visibility)            float64
# SUM(rest.Tdewpoint)             float64
# SUM(rest.rv1)                   float64
# SUM(rest.rv2)                   float64
#                                  ...
# MEAN(rest.RH_3)                 float64
# MEAN(rest.T4)                   float64
# MEAN(rest.RH_4)                 float64
# MEAN(rest.T5)                   float64
# MEAN(rest.RH_5)                 float64
# MEAN(rest.T6)                   float64
# MEAN(rest.RH_6)                 float64
# MEAN(rest.T7)                   float64
# MEAN(rest.RH_7)                 float64
# MEAN(rest.T8)                   float64
# MEAN(rest.RH_8)                 float64
# MEAN(rest.T9)                   float64
# MEAN(rest.RH_9)                 float64
# MEAN(rest.T_out)                float64
# MEAN(rest.Press_mm_hg)          float64
# MEAN(rest.RH_out)               float64
# MEAN(rest.Windspeed)            float64
# MEAN(rest.Visibility)           float64
# MEAN(rest.Tdewpoint)            float64
# MEAN(rest.rv1)                  float64
# MEAN(rest.rv2)                  float64
# MEAN(rest.Week_no)                int64
# NUM_UNIQUE(rest.day_of_week)      int64
# NUM_UNIQUE(rest.hour)             int64
# NUM_UNIQUE(rest.min)              int64
# NUM_UNIQUE(rest.period)           int64
# MODE(rest.day_of_week)           object
# MODE(rest.hour)                  object
# MODE(rest.min)                   object
# MODE(rest.period)                object
# Length: 189, dtype: object

# %%
y_featuretools1 = feature_matrix_app1[["Appliances"]]
X_featuretools1 = feature_matrix_app1.drop("Appliances",axis = 1)
y_featuretools1 = np.array(y_featuretools1)

# %%
type(y_featuretools1)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 2.2.1 Training Testing Spliting

# %%
X_train, X_test, y_train, y_test = train_test_split(X_featuretools1, y_featuretools1, test_size=0.30, random_state=42)

# %% [markdown]
# ### 2.2.2 RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
modelrandomforest = rf.fit(X_train,y_train)
randomforest = calc_error_metric(name,modelrandomforest,rf, X_train, y_train, X_test, y_test)
# Out:
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-667e63d0c3bb> in <module>()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# ----> 3 modelrandomforest = rf.fit(X_train,y_train)
#       4 randomforest = calc_error_metric(name,modelrandomforest,rf, X_train, y_train, X_test, y_test)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
phase_tsfresh
# Out:
#                  datetime  month day_of_week hour  day_number min period  \
# 0     2016-01-11 17:00:00      1           1   17          11   0   1170
# 1     2016-01-11 17:10:00      1           1   17          11  10  11710
# 2     2016-01-11 17:20:00      1           1   17          11  20  11720
# 3     2016-01-11 17:30:00      1           1   17          11  30  11730
# 4     2016-01-11 17:40:00      1           1   17          11  40  11740
# 5     2016-01-11 17:50:00      1           1   17          11  50  11750
# 6     2016-01-11 18:00:00      1           1   18          11   0   1180
# 7     2016-01-11 18:10:00      1           1   18          11  10  11810
# 8     2016-01-11 18:20:00      1           1   18          11  20  11820
# 9     2016-01-11 18:30:00      1           1   18          11  30  11830
# 10    2016-01-11 18:40:00      1           1   18          11  40  11840
# 11    2016-01-11 18:50:00      1           1   18          11  50  11850
# 12    2016-01-11 19:00:00      1           1   19          11   0   1190
# 13    2016-01-11 19:10:00      1           1   19          11  10  11910
# 14    2016-01-11 19:20:00      1           1   19          11  20  11920
# 15    2016-01-11 19:30:00      1           1   19          11  30  11930
# 16    2016-01-11 19:40:00      1           1   19          11  40  11940
# 17    2016-01-11 19:50:00      1           1   19          11  50  11950
# 18    2016-01-11 20:00:00      1           1   20          11   0   1200
# 19    2016-01-11 20:10:00      1           1   20          11  10  12010
# 20    2016-01-11 20:20:00      1           1   20          11  20  12020
# 21    2016-01-11 20:30:00      1           1   20          11  30  12030
# 22    2016-01-11 20:40:00      1           1   20          11  40  12040
# 23    2016-01-11 20:50:00      1           1   20          11  50  12050
# 24    2016-01-11 21:00:00      1           1   21          11   0   1210
# 25    2016-01-11 21:10:00      1           1   21          11  10  12110
# 26    2016-01-11 21:20:00      1           1   21          11  20  12120
# 27    2016-01-11 21:30:00      1           1   21          11  30  12130
# 28    2016-01-11 21:40:00      1           1   21          11  40  12140
# 29    2016-01-11 21:50:00      1           1   21          11  50  12150
# ...                   ...    ...         ...  ...         ...  ..    ...
y_tsfresh = phase_tsfresh['Appliances']

# %%
from tsfresh import extract_features
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute

extracted_features = extract_features(phase_tsfresh, column_id="datetime")
impute(extracted_features)
features_filtered = select_features(extracted_features, y_tsfresh)
# Out:
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/message.c:4294)
# KeyboardInterrupt
#
#
#
#
#
# Feature Extraction:   0%|          | 0/20 [00:00<?, ?it/s]
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 148, in run
#     for instance in self.tqdm_cls._instances:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     719             try:
# --> 720                 item = self._items.popleft()
#     721             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-6e49b3eafe64> in <module>()
#       5
#       6
# ----> 7 extracted_features = extract_features(phase_tsfresh, column_id="datetime")
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor)
#     150                                 default_fc_parameters=default_fc_parameters,
#     151                                 kind_to_fc_parameters=kind_to_fc_parameters,
# --> 152                                 distributor=distributor)
#     153
#     154         # Impute the result if requested
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in _do_extraction(df, column_id, column_value, column_kind, default_fc_parameters, kind_to_fc_parameters, n_jobs, chunk_size, disable_progressbar, distributor)
#     231     kwargs = dict(default_fc_parameters=default_fc_parameters, kind_to_fc_parameters=kind_to_fc_parameters)
#     232     result = distributor.map_reduce(_do_extraction_on_chunk, data=data_in_chunks, chunk_size=chunk_size,
# --> 233                                     function_kwargs=kwargs)
#     234     distributor.close()
#     235
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py in map_reduce(self, map_function, data, function_kwargs, chunk_size, data_length)
#     147             result = self.distribute(_function_with_partly_reduce, chunk_generator, map_kwargs),
#     148
# --> 149         result = list(itertools.chain.from_iterable(result))
#     150
#     151         return result
#
# ~/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     957 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     958
# --> 959             for obj in iterable:
#     960                 yield obj
#     961                 # Update and possibly print the progressbar.
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     722                 if self._index == self._length:
#     723                     raise StopIteration
# --> 724                 self._cond.wait(timeout)
#     725                 try:
#     726                     item = self._items.popleft()
#
# ~/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1254, in change_quantiles
#     bin_cat = pd.qcut(x, [ql, qh], labels=False)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 208, in qcut
#     dtype=dtype, duplicates=duplicates)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 239, in _bins_to_cuts
#     ids = _ensure_int64(bins.searchsorted(x, side=side))
# KeyboardInterrupt
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-19:
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1259, in change_quantiles
#     ind = (bin_cat_0 * np.roll(bin_cat_0, 1))[1:]
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py", line 1404, in roll
#     return roll(a.ravel(), shift, 0).reshape(a.shape)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py", line 1402, in roll
#     a = asanyarray(a)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1259, in change_quantiles
#     ind = (bin_cat_0 * np.roll(bin_cat_0, 1))[1:]
# KeyboardInterrupt
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py", line 1404, in roll
#     return roll(a.ravel(), shift, 0).reshape(a.shape)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py", line 1408, in roll
#     broadcasted = broadcast(shift, axis)
# KeyboardInterrupt
# Process ForkPoolWorker-17:
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1254, in change_quantiles
#     bin_cat = pd.qcut(x, [ql, qh], labels=False)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 208, in qcut
#     dtype=dtype, duplicates=duplicates)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 229, in _bins_to_cuts
#     unique_bins = algos.unique(bins)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py", line 363, in unique
#     table = htable(len(values))
# KeyboardInterrupt
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)

# %%
from tsfresh import extract_features
extracted_features = extract_features(phase_tsfresh, column_id="datetime", column_sort="hour")
# Out:
# Feature Extraction:   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     719             try:
# --> 720                 item = self._items.popleft()
#     721             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-4437bf71c715> in <module>()
#       1 from tsfresh import extract_features
# ----> 2 extracted_features = extract_features(phase_tsfresh, column_id="datetime", column_sort="hour")
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor)
#     150                                 default_fc_parameters=default_fc_parameters,
#     151                                 kind_to_fc_parameters=kind_to_fc_parameters,
# --> 152                                 distributor=distributor)
#     153
#     154         # Impute the result if requested
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in _do_extraction(df, column_id, column_value, column_kind, default_fc_parameters, kind_to_fc_parameters, n_jobs, chunk_size, disable_progressbar, distributor)
#     231     kwargs = dict(default_fc_parameters=default_fc_parameters, kind_to_fc_parameters=kind_to_fc_parameters)
#     232     result = distributor.map_reduce(_do_extraction_on_chunk, data=data_in_chunks, chunk_size=chunk_size,
# --> 233                                     function_kwargs=kwargs)
#     234     distributor.close()
#     235
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py in map_reduce(self, map_function, data, function_kwargs, chunk_size, data_length)
#     147             result = self.distribute(_function_with_partly_reduce, chunk_generator, map_kwargs),
#     148
# --> 149         result = list(itertools.chain.from_iterable(result))
#     150
#     151         return result
#
# ~/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     957 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     958
# --> 959             for obj in iterable:
#     960                 yield obj
#     961                 # Update and possibly print the progressbar.
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     722                 if self._index == self._length:
#     723                     raise StopIteration
# --> 724                 self._cond.wait(timeout)
#     725                 try:
#     726                     item = self._items.popleft()
#
# ~/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-12:
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1254, in change_quantiles
#     bin_cat = pd.qcut(x, [ql, qh], labels=False)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 208, in qcut
#     dtype=dtype, duplicates=duplicates)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 239, in _bins_to_cuts
#     ids = _ensure_int64(bins.searchsorted(x, side=side))
# KeyboardInterrupt
# Process ForkPoolWorker-11:
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
# Process ForkPoolWorker-10:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1254, in change_quantiles
#     bin_cat = pd.qcut(x, [ql, qh], labels=False)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 208, in qcut
#     dtype=dtype, duplicates=duplicates)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 229, in _bins_to_cuts
#     unique_bins = algos.unique(bins)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py", line 365, in unique
#     uniques = _reconstruct_data(uniques, dtype, original)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py", line 159, in _reconstruct_data
#     values = values.astype(dtype)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
# KeyboardInterrupt
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1254, in change_quantiles
#     bin_cat = pd.qcut(x, [ql, qh], labels=False)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 208, in qcut
#     dtype=dtype, duplicates=duplicates)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 229, in _bins_to_cuts
#     unique_bins = algos.unique(bins)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py", line 364, in unique
#     uniques = table.unique(values)
# KeyboardInterrupt
# Process ForkPoolWorker-9:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 888, in _find_spec
# AttributeError: 'VendorImporter' object has no attribute 'find_spec'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1254, in change_quantiles
#     bin_cat = pd.qcut(x, [ql, qh], labels=False)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py", line 205, in qcut
#     bins = algos.quantile(x, quantiles)
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py", line 899, in quantile
#     return algos.arrmap_float64(q, _get_score)
#   File "pandas/_libs/algos_common_helper.pxi", line 413, in pandas._libs.algos.arrmap_float64
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 951, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 890, in _find_spec
#   File "<frozen importlib._bootstrap>", line 864, in _find_spec_legacy
#   File "/Users/rishabhjain/anaconda3/lib/python3.6/site-packages/pkg_resources/extern/__init__.py", line 28, in find_module
#     root, base, target = fullname.partition(self.root_name + '.')
# KeyboardInterrupt
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1777: RuntimeWarning: invalid value encountered in double_scalars
#   res_data.append(np.sum(x[start:end]**2.0)/full_series_energy)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1422: RuntimeWarning: invalid value encountered in true_divide
#   similarity_ratio = A / B
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:1465: RuntimeWarning: invalid value encountered in double_scalars
#   return sum_product / ((len(x) - lag) * np.var(x))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/signal/spectral.py:1785: UserWarning: nperseg = 256 is greater than input length  = 1, using nperseg = 1
#   .format(nperseg, input_length))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:117: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /Users/rishabhjain/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py:897: RuntimeWarning: invalid value encountered in double_scalars
#   return y.dot(np.arange(len(y))**moment) / y.sum()

# %%
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute

impute(extracted_features)
features_filtered = select_features(extracted_features, y)
# Out:
# WARNING:tsfresh.utilities.dataframe_functions:The columns [ 'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"stderr"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"intercept"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"rvalue"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"slope"'
#  'Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"stderr"'
#  'Appliances__ar_coefficient__k_10__coeff_0'
#  'Appliances__ar_coefficient__k_10__coeff_1'
#  'Appliances__ar_coefficient__k_10__coeff_2'
#  'Appliances__ar_coefficient__k_10__coeff_3'
#  'Appliances__ar_coefficient__k_10__coeff_4'
#  'Appliances__augmented_dickey_fuller__attr_"pvalue"'
#  'Appliances__augmented_dickey_fuller__attr_"teststat"'
#  'Appliances__augmented_dickey_fuller__attr_"usedlag"'
#  'Appliances__autocorrelation__lag_0' 'Appliances__autocorrelation__lag_1'
#  'Appliances__autocorrelation__lag_2' 'Appliances__autocorrelation__lag_3'
#  'Appliances__autocorrelation__lag_4' 'Appliances__autocorrelation__lag_5'
#  'Appliances__autocorrelation__lag_6' 'Appliances__autocorrelation__lag_7'
#  'Appliances__autocorrelation__lag_8' 'Appliances__autocorrelation__lag_9'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_5'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20'
#  'Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_5'
#  'Appliances__fft_aggregated__aggtype_"kurtosis"'
#  'Appliances__fft_aggregated__aggtype_"skew"'
#  'Appliances__fft_coefficient__coeff_10__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_10__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_10__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_10__attr_"real"'
#  'Appliances__fft_coefficient__coeff_11__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_11__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_11__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_11__attr_"real"'
#  'Appliances__fft_coefficient__coeff_12__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_12__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_12__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_12__attr_"real"'
#  'Appliances__fft_coefficient__coeff_13__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_13__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_13__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_13__attr_"real"'
#  'Appliances__fft_coefficient__coeff_14__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_14__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_14__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_14__attr_"real"'
#  'Appliances__fft_coefficient__coeff_15__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_15__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_15__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_15__attr_"real"'
#  'Appliances__fft_coefficient__coeff_16__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_16__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_16__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_16__attr_"real"'
#  'Appliances__fft_coefficient__coeff_17__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_17__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_17__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_17__attr_"real"'
#  'Appliances__fft_coefficient__coeff_18__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_18__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_18__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_18__attr_"real"'
#  'Appliances__fft_coefficient__coeff_19__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_19__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_19__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_19__attr_"real"'
#  'Appliances__fft_coefficient__coeff_1__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_1__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_1__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_1__attr_"real"'
#  'Appliances__fft_coefficient__coeff_20__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_20__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_20__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_20__attr_"real"'
#  'Appliances__fft_coefficient__coeff_21__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_21__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_21__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_21__attr_"real"'
#  'Appliances__fft_coefficient__coeff_22__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_22__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_22__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_22__attr_"real"'
#  'Appliances__fft_coefficient__coeff_23__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_23__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_23__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_23__attr_"real"'
#  'Appliances__fft_coefficient__coeff_24__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_24__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_24__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_24__attr_"real"'
#  'Appliances__fft_coefficient__coeff_25__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_25__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_25__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_25__attr_"real"'
#  'Appliances__fft_coefficient__coeff_26__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_26__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_26__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_26__attr_"real"'
#  'Appliances__fft_coefficient__coeff_27__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_27__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_27__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_27__attr_"real"'
#  'Appliances__fft_coefficient__coeff_28__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_28__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_28__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_28__attr_"real"'
#  'Appliances__fft_coefficient__coeff_29__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_29__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_29__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_29__attr_"real"'
#  'Appliances__fft_coefficient__coeff_2__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_2__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_2__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_2__attr_"real"'
#  'Appliances__fft_coefficient__coeff_30__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_30__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_30__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_30__attr_"real"'
#  'Appliances__fft_coefficient__coeff_31__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_31__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_31__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_31__attr_"real"'
#  'Appliances__fft_coefficient__coeff_32__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_32__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_32__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_32__attr_"real"'
#  'Appliances__fft_coefficient__coeff_33__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_33__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_33__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_33__attr_"real"'
#  'Appliances__fft_coefficient__coeff_34__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_34__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_34__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_34__attr_"real"'
#  'Appliances__fft_coefficient__coeff_35__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_35__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_35__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_35__attr_"real"'
#  'Appliances__fft_coefficient__coeff_36__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_36__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_36__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_36__attr_"real"'
#  'Appliances__fft_coefficient__coeff_37__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_37__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_37__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_37__attr_"real"'
#  'Appliances__fft_coefficient__coeff_38__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_38__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_38__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_38__attr_"real"'
#  'Appliances__fft_coefficient__coeff_39__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_39__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_39__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_39__attr_"real"'
#  'Appliances__fft_coefficient__coeff_3__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_3__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_3__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_3__attr_"real"'
#  'Appliances__fft_coefficient__coeff_40__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_40__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_40__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_40__attr_"real"'
#  'Appliances__fft_coefficient__coeff_41__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_41__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_41__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_41__attr_"real"'
#  'Appliances__fft_coefficient__coeff_42__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_42__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_42__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_42__attr_"real"'
#  'Appliances__fft_coefficient__coeff_43__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_43__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_43__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_43__attr_"real"'
#  'Appliances__fft_coefficient__coeff_44__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_44__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_44__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_44__attr_"real"'
#  'Appliances__fft_coefficient__coeff_45__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_45__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_45__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_45__attr_"real"'
#  'Appliances__fft_coefficient__coeff_46__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_46__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_46__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_46__attr_"real"'
#  'Appliances__fft_coefficient__coeff_47__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_47__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_47__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_47__attr_"real"'
#  'Appliances__fft_coefficient__coeff_48__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_48__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_48__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_48__attr_"real"'
#  'Appliances__fft_coefficient__coeff_49__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_49__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_49__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_49__attr_"real"'
#  'Appliances__fft_coefficient__coeff_4__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_4__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_4__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_4__attr_"real"'
#  'Appliances__fft_coefficient__coeff_50__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_50__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_50__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_50__attr_"real"'
#  'Appliances__fft_coefficient__coeff_51__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_51__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_51__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_51__attr_"real"'
#  'Appliances__fft_coefficient__coeff_52__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_52__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_52__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_52__attr_"real"'
#  'Appliances__fft_coefficient__coeff_53__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_53__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_53__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_53__attr_"real"'
#  'Appliances__fft_coefficient__coeff_54__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_54__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_54__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_54__attr_"real"'
#  'Appliances__fft_coefficient__coeff_55__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_55__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_55__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_55__attr_"real"'
#  'Appliances__fft_coefficient__coeff_56__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_56__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_56__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_56__attr_"real"'
#  'Appliances__fft_coefficient__coeff_57__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_57__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_57__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_57__attr_"real"'
#  'Appliances__fft_coefficient__coeff_58__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_58__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_58__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_58__attr_"real"'
#  'Appliances__fft_coefficient__coeff_59__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_59__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_59__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_59__attr_"real"'
#  'Appliances__fft_coefficient__coeff_5__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_5__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_5__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_5__attr_"real"'
#  'Appliances__fft_coefficient__coeff_60__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_60__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_60__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_60__attr_"real"'
#  'Appliances__fft_coefficient__coeff_61__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_61__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_61__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_61__attr_"real"'
#  'Appliances__fft_coefficient__coeff_62__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_62__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_62__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_62__attr_"real"'
#  'Appliances__fft_coefficient__coeff_63__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_63__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_63__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_63__attr_"real"'
#  'Appliances__fft_coefficient__coeff_64__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_64__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_64__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_64__attr_"real"'
#  'Appliances__fft_coefficient__coeff_65__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_65__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_65__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_65__attr_"real"'
#  'Appliances__fft_coefficient__coeff_66__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_66__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_66__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_66__attr_"real"'
#  'Appliances__fft_coefficient__coeff_67__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_67__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_67__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_67__attr_"real"'
#  'Appliances__fft_coefficient__coeff_68__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_68__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_68__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_68__attr_"real"'
#  'Appliances__fft_coefficient__coeff_69__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_69__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_69__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_69__attr_"real"'
#  'Appliances__fft_coefficient__coeff_6__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_6__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_6__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_6__attr_"real"'
#  'Appliances__fft_coefficient__coeff_70__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_70__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_70__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_70__attr_"real"'
#  'Appliances__fft_coefficient__coeff_71__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_71__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_71__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_71__attr_"real"'
#  'Appliances__fft_coefficient__coeff_72__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_72__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_72__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_72__attr_"real"'
#  'Appliances__fft_coefficient__coeff_73__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_73__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_73__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_73__attr_"real"'
#  'Appliances__fft_coefficient__coeff_74__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_74__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_74__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_74__attr_"real"'
#  'Appliances__fft_coefficient__coeff_75__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_75__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_75__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_75__attr_"real"'
#  'Appliances__fft_coefficient__coeff_76__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_76__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_76__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_76__attr_"real"'
#  'Appliances__fft_coefficient__coeff_77__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_77__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_77__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_77__attr_"real"'
#  'Appliances__fft_coefficient__coeff_78__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_78__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_78__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_78__attr_"real"'
#  'Appliances__fft_coefficient__coeff_79__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_79__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_79__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_79__attr_"real"'
#  'Appliances__fft_coefficient__coeff_7__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_7__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_7__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_7__attr_"real"'
#  'Appliances__fft_coefficient__coeff_80__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_80__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_80__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_80__attr_"real"'
#  'Appliances__fft_coefficient__coeff_81__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_81__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_81__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_81__attr_"real"'
#  'Appliances__fft_coefficient__coeff_82__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_82__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_82__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_82__attr_"real"'
#  'Appliances__fft_coefficient__coeff_83__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_83__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_83__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_83__attr_"real"'
#  'Appliances__fft_coefficient__coeff_84__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_84__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_84__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_84__attr_"real"'
#  'Appliances__fft_coefficient__coeff_85__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_85__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_85__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_85__attr_"real"'
#  'Appliances__fft_coefficient__coeff_86__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_86__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_86__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_86__attr_"real"'
#  'Appliances__fft_coefficient__coeff_87__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_87__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_87__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_87__attr_"real"'
#  'Appliances__fft_coefficient__coeff_88__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_88__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_88__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_88__attr_"real"'
#  'Appliances__fft_coefficient__coeff_89__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_89__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_89__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_89__attr_"real"'
#  'Appliances__fft_coefficient__coeff_8__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_8__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_8__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_8__attr_"real"'
#  'Appliances__fft_coefficient__coeff_90__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_90__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_90__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_90__attr_"real"'
#  'Appliances__fft_coefficient__coeff_91__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_91__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_91__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_91__attr_"real"'
#  'Appliances__fft_coefficient__coeff_92__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_92__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_92__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_92__attr_"real"'
#  'Appliances__fft_coefficient__coeff_93__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_93__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_93__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_93__attr_"real"'
#  'Appliances__fft_coefficient__coeff_94__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_94__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_94__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_94__attr_"real"'
#  'Appliances__fft_coefficient__coeff_95__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_95__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_95__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_95__attr_"real"'
#  'Appliances__fft_coefficient__coeff_96__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_96__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_96__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_96__attr_"real"'
#  'Appliances__fft_coefficient__coeff_97__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_97__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_97__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_97__attr_"real"'
#  'Appliances__fft_coefficient__coeff_98__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_98__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_98__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_98__attr_"real"'
#  'Appliances__fft_coefficient__coeff_99__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_99__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_99__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_99__attr_"real"'
#  'Appliances__fft_coefficient__coeff_9__attr_"abs"'
#  'Appliances__fft_coefficient__coeff_9__attr_"angle"'
#  'Appliances__fft_coefficient__coeff_9__attr_"imag"'
#  'Appliances__fft_coefficient__coeff_9__attr_"real"'
#  'Appliances__friedrich_coefficients__m_3__r_30__coeff_0'
#  'Appliances__friedrich_coefficients__m_3__r_30__coeff_1'
#  'Appliances__friedrich_coefficients__m_3__r_30__coeff_2'
#  'Appliances__friedrich_coefficients__m_3__r_30__coeff_3'
#  'Appliances__kurtosis' 'Appliances__linear_trend__attr_"intercept"'
#  'Appliances__linear_trend__attr_"pvalue"'
#  'Appliances__linear_trend__attr_"slope"'
#  'Appliances__linear_trend__attr_"stderr"'
#  'Appliances__max_langevin_fixed_point__m_3__r_30'
#  'Appliances__mean_abs_change' 'Appliances__mean_change'
#  'Appliances__mean_second_derivative_central'
#  'Appliances__partial_autocorrelation__lag_0'
#  'Appliances__partial_autocorrelation__lag_1'
#  'Appliances__partial_autocorrelation__lag_2'
#  'Appliances__partial_autocorrelation__lag_3'
#  'Appliances__partial_autocorrelation__lag_4'
#  'Appliances__partial_autocorrelation__lag_5'
#  'Appliances__partial_autocorrelation__lag_6'
#  'Appliances__partial_autocorrelation__lag_7'
#  'Appliances__partial_autocorrelation__lag_8'
#  'Appliances__partial_autocorrelation__lag_9' 'Appliances__sample_entropy'
#  'Appliances__skewness' 'Appliances__spkt_welch_density__coeff_2'
#  'Appliances__spkt_welch_density__coeff_5'
#  'Appliances__spkt_welch_density__coeff_8'] did not have any finite values. Filling with zeros.
# WARNING:tsfresh.feature_selection.relevance:Infered classification as machine learning task
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__absolute_sum_of_changes is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_autocorrelation__f_agg_"var" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_autocorrelation__f_agg_"mean" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_autocorrelation__f_agg_"median" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__approximate_entropy__m_2__r_0.1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__approximate_entropy__m_2__r_0.3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__approximate_entropy__m_2__r_0.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__approximate_entropy__m_2__r_0.7 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__approximate_entropy__m_2__r_0.9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ar_coefficient__k_10__coeff_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ar_coefficient__k_10__coeff_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ar_coefficient__k_10__coeff_2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ar_coefficient__k_10__coeff_3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ar_coefficient__k_10__coeff_4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__augmented_dickey_fuller__attr_"pvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__augmented_dickey_fuller__attr_"teststat" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__augmented_dickey_fuller__attr_"usedlag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_7 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__autocorrelation__lag_9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__binned_entropy__max_bins_10 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__c3__lag_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__c3__lag_2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__c3__lag_3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0 is constant
# ...
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__fft_coefficient__coeff_97__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__fft_coefficient__coeff_98__attr_"angle" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__fft_coefficient__coeff_98__attr_"abs" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__fft_coefficient__coeff_98__attr_"imag" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__fft_coefficient__coeff_98__attr_"real" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.7 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__linear_trend__attr_"rvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__linear_trend__attr_"slope" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__linear_trend__attr_"stderr" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__index_mass_quantile__q_0.9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__longest_strike_above_mean is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__kurtosis is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.05 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__longest_strike_below_mean is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__max_langevin_fixed_point__m_3__r_30 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.15000000000000002 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__mean_abs_change is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__mean_change is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.25 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__mean_second_derivative_central is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.30000000000000004 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.35000000000000003 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_crossing_m__m_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_crossing_m__m_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.45 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_crossing_m__m_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_cwt_peaks__n_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.55 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_cwt_peaks__n_5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.6000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_peaks__n_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_peaks__n_10 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.65 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_peaks__n_3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.7000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_peaks__n_5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.75 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__number_peaks__n_50 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.8500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_7 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__large_standard_deviation__r_0.9500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_value_number_to_time_series_length is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__last_location_of_maximum is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__last_location_of_minimum is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__sample_entropy is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_6 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__skewness is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__length is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_7 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__spkt_welch_density__coeff_2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__linear_trend__attr_"intercept" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__spkt_welch_density__coeff_5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__linear_trend__attr_"pvalue" is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__partial_autocorrelation__lag_9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__spkt_welch_density__coeff_8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__percentage_of_reoccurring_datapoints_to_all_datapoints is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__standard_deviation is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__percentage_of_reoccurring_values_to_all_values is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__sum_of_reoccurring_data_points is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__sum_of_reoccurring_values is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.05 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__range_count__max_1__min_-1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.15000000000000002 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_0.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.25 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_1.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.30000000000000004 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_10 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.35000000000000003 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__ratio_beyond_r_sigma__r_2.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.4 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.45 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.5 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.55 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.6000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.65 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.7000000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.75 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.8 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.8500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.9 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__symmetry_looking__r_0.9500000000000001 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__time_reversal_asymmetry_statistic__lag_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__time_reversal_asymmetry_statistic__lag_2 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__time_reversal_asymmetry_statistic__lag_3 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__value_count__value_-inf is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__value_count__value_0 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__value_count__value_1 is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__value_count__value_inf is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__value_count__value_nan is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__variance is constant
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature Appliances__variance_larger_than_standard_deviation is constant

# %%
features_filtered.dtypes
# Out:
# variable
# Appliances__abs_energy                                                float64
# Appliances__quantile__q_0.8                                           float64
# Appliances__quantile__q_0.7                                           float64
# Appliances__quantile__q_0.6                                           float64
# Appliances__quantile__q_0.4                                           float64
# Appliances__quantile__q_0.3                                           float64
# Appliances__quantile__q_0.2                                           float64
# Appliances__quantile__q_0.1                                           float64
# Appliances__minimum                                                   float64
# Appliances__median                                                    float64
# Appliances__mean                                                      float64
# Appliances__maximum                                                   float64
# Appliances__fft_coefficient__coeff_0__attr_"real"                     float64
# Appliances__fft_coefficient__coeff_0__attr_"abs"                      float64
# Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_5     float64
# Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_20    float64
# Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_2     float64
# Appliances__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_10    float64
# Appliances__quantile__q_0.9                                           float64
# Appliances__sum_values                                                float64
# dtype: object

# %%
# For Extracing Minimal Features
from tsfresh.feature_extraction import MinimalFCParameters
extracted_features = extract_features(phase, column_id="datetime", column_sort="period",show_warnings=False, default_fc_parameters=MinimalFCParameters())

# %%
y_featuretools1 = np.array(y_featuretools1)

# %%
X_featuretools2 = X_featuretools1.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-8d2699119dd2> in <module>()
# ----> 1 X_featuretools2 = X_featuretools1.values
#
# AttributeError: 'NoneType' object has no attribute 'values'

# %%
X_featuretools1

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(X_featuretools1,y_featuretools1, test_size = 0.25, random_state = 42)
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(train_features, train_labels)
predictions = rf.predict(test_features)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e1e12de4c1dd> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2 # Split the data into training and testing sets
# ----> 3 train_features, test_features, train_labels, test_labels = train_test_split(X_featuretools1,y_featuretools1, test_size = 0.25, random_state = 42)
#       4 from sklearn.ensemble import RandomForestRegressor
#       5 rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2054                      random_state=random_state)
#    2055
# -> 2056         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2057
#    2058     return list(chain.from_iterable((safe_indexing(a, train),
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1202         """
#    1203         X, y, groups = indexable(X, y, groups)
# -> 1204         for train, test in self._iter_indices(X, y, groups):
#    1205             yield train, test
#    1206
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1299
#    1300     def _iter_indices(self, X, y=None, groups=None):
# -> 1301         n_samples = _num_samples(X)
#    1302         n_train, n_test = _validate_shuffle_split(n_samples,
#    1303                                                   self.test_size,
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     113         else:
#     114             raise TypeError("Expected sequence or array-like, got %s" %
# --> 115                             type(x))
#     116     if hasattr(x, 'shape'):
#     117         if len(x.shape) == 0:
#
# TypeError: Expected sequence or array-like, got <class 'NoneType'>

# %%
# 2.2.3 Random

# %%
phase
# Out:
#                      month  day_of_week  hour  day_number  min  period  \
# date
# 2016-01-11 17:00:00      1            1    17          11    0    1170
# 2016-01-11 17:10:00      1            1    17          11   10   11710
# 2016-01-11 17:20:00      1            1    17          11   20   11720
# 2016-01-11 17:30:00      1            1    17          11   30   11730
# 2016-01-11 17:40:00      1            1    17          11   40   11740
# 2016-01-11 17:50:00      1            1    17          11   50   11750
# 2016-01-11 18:00:00      1            1    18          11    0    1180
# 2016-01-11 18:10:00      1            1    18          11   10   11810
# 2016-01-11 18:20:00      1            1    18          11   20   11820
# 2016-01-11 18:30:00      1            1    18          11   30   11830
# 2016-01-11 18:40:00      1            1    18          11   40   11840
# 2016-01-11 18:50:00      1            1    18          11   50   11850
# 2016-01-11 19:00:00      1            1    19          11    0    1190
# 2016-01-11 19:10:00      1            1    19          11   10   11910
# 2016-01-11 19:20:00      1            1    19          11   20   11920
# 2016-01-11 19:30:00      1            1    19          11   30   11930
# 2016-01-11 19:40:00      1            1    19          11   40   11940
# 2016-01-11 19:50:00      1            1    19          11   50   11950
# 2016-01-11 20:00:00      1            1    20          11    0    1200
# 2016-01-11 20:10:00      1            1    20          11   10   12010
# 2016-01-11 20:20:00      1            1    20          11   20   12020
# 2016-01-11 20:30:00      1            1    20          11   30   12030
# 2016-01-11 20:40:00      1            1    20          11   40   12040
# 2016-01-11 20:50:00      1            1    20          11   50   12050
# 2016-01-11 21:00:00      1            1    21          11    0    1210
# 2016-01-11 21:10:00      1            1    21          11   10   12110
# 2016-01-11 21:20:00      1            1    21          11   20   12120
# 2016-01-11 21:30:00      1            1    21          11   30   12130
# 2016-01-11 21:40:00      1            1    21          11   40   12140
# 2016-01-11 21:50:00      1            1    21          11   50   12150
# ...                    ...          ...   ...         ...  ...     ...
# 2016-05-27 13:10:00      5            5    13          27   10   51310
# 2016-05-27 13:20:00      5            5    13          27   20   51320
# 2016-05-27 13:30:00      5            5    13          27   30   51330
# 2016-05-27 13:40:00      5            5    13          27   40   51340
# 2016-05-27 13:50:00      5            5    13          27   50   51350
# 2016-05-27 14:00:00      5            5    14          27    0    5140
# 2016-01-11 21:40:00  87.666667   6.000000    3.688879   3.766667        2
# 2016-01-11 21:50:00  87.833333   6.000000    3.688879   3.733333        2
# ...                        ...        ...         ...        ...      ...
# 2016-05-27 13:10:00  59.833333   1.166667    3.164068  13.100000       21
# 2016-05-27 13:20:00  59.666667   1.333333    3.149883  13.200000       21
# 2016-05-27 13:30:00  59.500000   1.500000    3.135494  13.300000       21
# 2016-05-27 13:40:00  59.333333   1.666667    3.120895  13.400000       21
# 2016-05-27 13:50:00  59.166667   1.833333    3.106080  13.500000       21
# 2016-05-27 14:00:00  59.000000   2.000000    3.091042  13.600000       21
# 2016-05-27 14:10:00  59.000000   2.000000    3.083438  13.550000       21
# 2016-05-27 14:20:00  59.000000   2.000000    3.075775  13.500000       21
# 2016-05-27 14:30:00  59.000000   2.000000    3.068053  13.450000       21
# 2016-05-27 14:40:00  59.000000   2.000000    3.060271  13.400000       21
# 2016-05-27 14:50:00  59.000000   2.000000    3.052428  13.350000       21
# 2016-05-27 15:00:00  59.000000   2.000000    3.044522  13.300000       21
# 2016-05-27 15:10:00  58.333333   2.000000    3.060271  13.283333       21
# 2016-05-27 15:20:00  57.666667   2.000000    3.075775  13.266667       21
# 2016-05-27 15:30:00  57.000000   2.000000    3.091042  13.250000       21
# 2016-05-27 15:40:00  56.333333   2.000000    3.106080  13.233333       21
# 2016-05-27 15:50:00  55.666667   2.000000    3.120895  13.216667       21
# 2016-05-27 16:00:00  55.000000   2.000000    3.135494  13.200000       21
# 2016-05-27 16:10:00  55.000000   2.166667    3.128221  13.233333       21
# 2016-05-27 16:20:00  55.000000   2.333333    3.120895  13.266667       21
# 2016-05-27 16:30:00  55.000000   2.500000    3.113515  13.300000       21
# 2016-05-27 16:40:00  55.000000   2.666667    3.106080  13.333333       21
# 2016-05-27 16:50:00  55.000000   2.833333    3.098590  13.366667       21
# 2016-05-27 17:00:00  55.000000   3.000000    3.091042  13.400000       21
# 2016-05-27 17:10:00  55.333333   3.166667    3.128221  13.366667       21
# 2016-05-27 17:20:00  55.666667   3.333333    3.164068  13.333333       21
# 2016-05-27 17:30:00  56.000000   3.500000    3.198673  13.300000       21
# 2016-05-27 17:40:00  56.333333   3.666667    3.232121  13.266667       21
# 2016-05-27 17:50:00  56.666667   3.833333    3.264486  13.233333       21
# 2016-05-27 18:00:00  57.000000   4.000000    3.295837  13.200000       21
#
# [19735 rows x 33 columns]

# %%
phase.dtypes
# Out:
# month            int64
# day_of_week      int64
# hour             int64
# day_number       int64
# min              int64
# period           int64
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# Week_no          int64
# dtype: object

# %%
y_boruta = y.values
